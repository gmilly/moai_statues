# %%
import os
import xarray as xr
import s3fs
import fsspec

# %%
OSN_ENDPOINT_URL = "https://nyu1.osn.mghpcc.org"
OSN_BUCKET = "leap-pangeo-manual"
HACKATHON_PREFIX = "hackathon-2026/"

# %%
OSN_ROOT = f"s3://{OSN_BUCKET}/{HACKATHON_PREFIX}" 

# For this hackathon: s3://leap-pangeo-manual/hackathon-2026/

# %%
# Anonymous access to a public OSN endpoint
fs_osn = s3fs.S3FileSystem(
    anon=True,
    client_kwargs={"endpoint_url": OSN_ENDPOINT_URL},
)

# Test: list top-level within the hackathon prefix
fs_osn.ls(f"{OSN_BUCKET}/{HACKATHON_PREFIX}")[:20]
# Out:
# ['leap-pangeo-manual/hackathon-2026/corrdiff',
#  'leap-pangeo-manual/hackathon-2026/era5_cds',
#  'leap-pangeo-manual/hackathon-2026/hrrr']

# %%
fs_osn.ls(f"{OSN_BUCKET}/{HACKATHON_PREFIX}era5_cds/")[:20]
# Out:
# ['leap-pangeo-manual/hackathon-2026/era5_cds/NYC']

# %%
fs_osn.ls(f"{OSN_BUCKET}/{HACKATHON_PREFIX}era5_cds/NYC/")[:20]
# Out:
# ['leap-pangeo-manual/hackathon-2026/era5_cds/NYC/era5NYC1945.zarr',
#  'leap-pangeo-manual/hackathon-2026/era5_cds/NYC/era5NYC1955.zarr',
#  'leap-pangeo-manual/hackathon-2026/era5_cds/NYC/era5NYC1965.zarr',
#  'leap-pangeo-manual/hackathon-2026/era5_cds/NYC/era5NYC1975.zarr',
#  'leap-pangeo-manual/hackathon-2026/era5_cds/NYC/era5NYC1985.zarr',
#  'leap-pangeo-manual/hackathon-2026/era5_cds/NYC/era5NYC1995.zarr',
#  'leap-pangeo-manual/hackathon-2026/era5_cds/NYC/era5NYC2005.zarr',
#  'leap-pangeo-manual/hackathon-2026/era5_cds/NYC/era5NYC2012.zarr',
#  'leap-pangeo-manual/hackathon-2026/era5_cds/NYC/era5NYC2015.zarr',
#  'leap-pangeo-manual/hackathon-2026/era5_cds/NYC/era5NYC2019.zarr',
#  'leap-pangeo-manual/hackathon-2026/era5_cds/NYC/era5NYC2020.zarr',
#  'leap-pangeo-manual/hackathon-2026/era5_cds/NYC/era5NYC2021.zarr',
#  'leap-pangeo-manual/hackathon-2026/era5_cds/NYC/era5NYC2022.zarr',
#  'leap-pangeo-manual/hackathon-2026/era5_cds/NYC/era5NYC2023.zarr',
#  'leap-pangeo-manual/hackathon-2026/era5_cds/NYC/era5NYC2024.zarr',
#  'leap-pangeo-manual/hackathon-2026/era5_cds/NYC/era5NYC2025.zarr']

# %%
fs_osn.ls(f"{OSN_BUCKET}/{HACKATHON_PREFIX}hrrr")[:20]
# Out:
# ['leap-pangeo-manual/hackathon-2026/hrrr/refc',
#  'leap-pangeo-manual/hackathon-2026/hrrr/temp2m',
#  'leap-pangeo-manual/hackathon-2026/hrrr/tp',
#  'leap-pangeo-manual/hackathon-2026/hrrr/u10m',
#  'leap-pangeo-manual/hackathon-2026/hrrr/v10m']

# %%
fs_osn.ls(f"{OSN_BUCKET}/{HACKATHON_PREFIX}corrdiff")[:50]
# Out:
# ['leap-pangeo-manual/hackathon-2026/corrdiff/ERA5_hrrr_interp_128_2020.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/ERA5_hrrr_interp_128_2021.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/ERA5_hrrr_interp_128_2021_1.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/ERA5_hrrr_interp_128_2021_2.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/ERA5_hrrr_interp_128_2022.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/ERA5_hrrr_interp_128_2023.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/ERA5_hrrr_interp_128_2024.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/ERA5_hrrr_interp_128_2025.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/corrdiff_weights',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/hrrr_NYC_128_2020_2025.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/hrrr_NYC_128_2021.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/hrrr_NYC_128_2021_1.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/hrrr_NYC_128_2021_2.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/hrrr_NYC_128_2022.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/hrrr_NYC_128_2023.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/hrrr_NYC_128_2024.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/hrrr_NYC_128_2025.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/input_1945.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/input_1955.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/input_1965.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/input_1975.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/input_1985.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/input_1995.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/input_2005.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/input_2020.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/input_2021.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/input_2025.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/output_1945.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/output_1955.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/output_1965.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/output_1975.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/output_1985.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/output_1995.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/output_2005.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/output_2020.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/output_2021.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/output_2025.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/target_1945.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/target_1955.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/target_1965.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/target_1975.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/target_1985.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/target_1995.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/target_2005.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/target_2020.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/target_2021.nc',
#  'leap-pangeo-manual/hackathon-2026/corrdiff/target_2025.nc']

# %%
year="1945"

# %%
#Example: replace with a real Zarr path you discover via listing
example_zarr_path = f"{OSN_BUCKET}/{HACKATHON_PREFIX}era5_cds/NYC/era5NYC{year}.zarr"

mapper = fs_osn.get_mapper(example_zarr_path)

# Open dataset
ds = xr.open_zarr(mapper, consolidated=False)  # consolidated=True if metadata consolidated

ds
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:    (time: 8760, latitude: 44, longitude: 57)
# Coordinates:
#   * time       (time) datetime64[ns] 70kB 1945-01-01 ... 1945-12-31T23:00:00
#   * latitude   (latitude) float32 176B 46.05 45.8 45.55 45.3 ... 35.8 35.55 35.3
#   * longitude  (longitude) float32 228B -81.1 -80.85 -80.6 ... -67.35 -67.1
# Data variables: (12/13)
#     t2m        (time, latitude, longitude) float64 176MB dask.array<chunksize=(168, 44, 57), meta=np.ndarray>
#     t_500      (time, latitude, longitude) float64 176MB dask.array<chunksize=(168, 44, 57), meta=np.ndarray>
#     t_850      (time, latitude, longitude) float64 176MB dask.array<chunksize=(168, 44, 57), meta=np.ndarray>
#     tcwv       (time, latitude, longitude) float64 176MB dask.array<chunksize=(168, 44, 57), meta=np.ndarray>
#     tp         (time, latitude, longitude) float64 176MB dask.array<chunksize=(168, 44, 57), meta=np.ndarray>
#     u10        (time, latitude, longitude) float64 176MB dask.array<chunksize=(168, 44, 57), meta=np.ndarray>
#     ...         ...
#     u_850      (time, latitude, longitude) float64 176MB dask.array<chunksize=(168, 44, 57), meta=np.ndarray>
#     v10        (time, latitude, longitude) float64 176MB dask.array<chunksize=(168, 44, 57), meta=np.ndarray>
#     v_500      (time, latitude, longitude) float64 176MB dask.array<chunksize=(168, 44, 57), meta=np.ndarray>
#     v_850      (time, latitude, longitude) float64 176MB dask.array<chunksize=(168, 44, 57), meta=np.ndarray>
#     z_500      (time, latitude, longitude) float64 176MB dask.array<chunksize=(168, 44, 57), meta=np.ndarray>
#     z_850      (time, latitude, longitude) float64 176MB dask.array<chunksize=(168, 44, 57), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     history:      2025-12-06 22:13:12 GMT by grib_to_netcdf-2.42.0: grib_to_n...

# %%
# Path to CorrDiff NetCDF
corrdiff_nc = f"s3://{OSN_BUCKET}/{HACKATHON_PREFIX}corrdiff/output_2020.nc"

# %%
ds_nc = xr.open_dataset(
    corrdiff_nc,
    engine="h5netcdf",
    storage_options={
        "anon": True,
        "client_kwargs": {"endpoint_url": OSN_ENDPOINT_URL}
    }
)
print(ds_nc)  # Check variables/dimensions
# Out:
# <xarray.Dataset> Size: 58GB
# Dimensions:              (time: 8783, ensemble: 10, y: 128, x: 128)
# Coordinates:
#   * time                 (time) datetime64[ns] 70kB 2020-01-01 ... 2020-12-31...
#     atmosphere           float64 8B ...
#     gribfile_projection  float64 8B ...
#     step                 timedelta64[ns] 8B ...
#     valid_time           (time) datetime64[ns] 70kB ...
#     latitude             (y, x) float64 131kB ...
#     longitude            (y, x) float64 131kB ...
#     surface              float64 8B ...
#     valid_time_tp        (time) datetime64[ns] 70kB ...
# Dimensions without coordinates: ensemble, y, x
# Data variables:
#     refc                 (time, ensemble, y, x) float64 12GB ...
#     t2m                  (time, ensemble, y, x) float64 12GB ...
#     u10                  (time, ensemble, y, x) float64 12GB ...
#     v10                  (time, ensemble, y, x) float64 12GB ...
#     tp                   (time, ensemble, y, x) float64 12GB ...

# %%
import gcsfs

fs = gcsfs.GCSFileSystem()  # uses ADC automatically

# List top-level objects and prefixes
fs.ls("leap-scratch")
# Out:
# ['leap-scratch/CMIS2023_EN',
#  'leap-scratch/NTA_Outdoor_Heat_Index.csv',
#  'leap-scratch/giant_sequoias',
#  'leap-scratch/hackathon-2026',
#  'leap-scratch/komododragons',
#  'leap-scratch/maui-statues',
#  'leap-scratch/renriviera',
#  'leap-scratch/starsofindia',
#  'leap-scratch/zero734kr']

# %%
#select nearest grid cell from ERA5 data
ds_bv=ds.sel(latitude=40.66,longitude=-73.91,method='nearest')
ds_bv
# Out:
# <xarray.Dataset> Size: 981kB
# Dimensions:    (time: 8760)
# Coordinates:
#   * time       (time) datetime64[ns] 70kB 1945-01-01 ... 1945-12-31T23:00:00
#     latitude   float32 4B 40.55
#     longitude  float32 4B -73.85
# Data variables: (12/13)
#     t2m        (time) float64 70kB dask.array<chunksize=(168,), meta=np.ndarray>
#     t_500      (time) float64 70kB dask.array<chunksize=(168,), meta=np.ndarray>
#     t_850      (time) float64 70kB dask.array<chunksize=(168,), meta=np.ndarray>
#     tcwv       (time) float64 70kB dask.array<chunksize=(168,), meta=np.ndarray>
#     tp         (time) float64 70kB dask.array<chunksize=(168,), meta=np.ndarray>
#     u10        (time) float64 70kB dask.array<chunksize=(168,), meta=np.ndarray>
#     ...         ...
#     u_850      (time) float64 70kB dask.array<chunksize=(168,), meta=np.ndarray>
#     v10        (time) float64 70kB dask.array<chunksize=(168,), meta=np.ndarray>
#     v_500      (time) float64 70kB dask.array<chunksize=(168,), meta=np.ndarray>
#     v_850      (time) float64 70kB dask.array<chunksize=(168,), meta=np.ndarray>
#     z_500      (time) float64 70kB dask.array<chunksize=(168,), meta=np.ndarray>
#     z_850      (time) float64 70kB dask.array<chunksize=(168,), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     history:      2025-12-06 22:13:12 GMT by grib_to_netcdf-2.42.0: grib_to_n...

# %%
ds_bv_jja=ds_bv.isel(time=slice(151*24,243*24))
ds_bv_jja
# Out:
# <xarray.Dataset> Size: 247kB
# Dimensions:    (time: 2208)
# Coordinates:
#   * time       (time) datetime64[ns] 18kB 1945-06-01 ... 1945-08-31T23:00:00
#     latitude   float32 4B 40.55
#     longitude  float32 4B -73.85
# Data variables: (12/13)
#     t2m        (time) float64 18kB dask.array<chunksize=(72,), meta=np.ndarray>
#     t_500      (time) float64 18kB dask.array<chunksize=(72,), meta=np.ndarray>
#     t_850      (time) float64 18kB dask.array<chunksize=(72,), meta=np.ndarray>
#     tcwv       (time) float64 18kB dask.array<chunksize=(72,), meta=np.ndarray>
#     tp         (time) float64 18kB dask.array<chunksize=(72,), meta=np.ndarray>
#     u10        (time) float64 18kB dask.array<chunksize=(72,), meta=np.ndarray>
#     ...         ...
#     u_850      (time) float64 18kB dask.array<chunksize=(72,), meta=np.ndarray>
#     v10        (time) float64 18kB dask.array<chunksize=(72,), meta=np.ndarray>
#     v_500      (time) float64 18kB dask.array<chunksize=(72,), meta=np.ndarray>
#     v_850      (time) float64 18kB dask.array<chunksize=(72,), meta=np.ndarray>
#     z_500      (time) float64 18kB dask.array<chunksize=(72,), meta=np.ndarray>
#     z_850      (time) float64 18kB dask.array<chunksize=(72,), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     history:      2025-12-06 22:13:12 GMT by grib_to_netcdf-2.42.0: grib_to_n...

# %%
temp=ds_bv_jja['t2m'].values

# %%
print(temp[0:20])
# Out:
# [288.29393115 287.60061926 285.30777679 284.63387521 284.24991508
#  283.1696102  283.13139616 283.20115195 282.00923781 281.97163034
#  283.03677091 283.01250803 283.30123634 283.51899572 285.64745716
#  286.06963133 286.57369273 288.26299598 288.76038508 289.10309831]

# %%
print(temp.mean())
# Out:
# 294.6324601561709

# %%
print(temp.max())
# Out:
# 304.50699634466724

# %%
print((temp.mean()-273.15)*(9./5.)+32.)
# Out:
# 70.66842828110768

# %%
print((temp.max()-273.15)*(9./5.)+32.)
# Out:
# 88.44259342040108
